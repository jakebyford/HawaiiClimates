# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import seaborn as sb

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import extract

# %%
# Create our engine aka where the data is being pulled
engine = create_engine("sqlite:///../Resources/hawaii.sqlite", echo = False)

# %%
# reflect an existing database into a new model
Base = automap_base()
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
# reflect the tables
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# Print the first row in the Measurement table
first_row = session.query(Measurement).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x18bf91ff708>,
#  'id': 1,
#  'station': 'USC00519397',
#  'prcp': 0.08,
#  'tobs': 65.0,
#  'date': '2010-01-01'}

# %%
# Print the first row in the Station table
first_row = session.query(Station).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x18bf9280788>,
#  'name': 'WAIKIKI 717.2, HI US',
#  'longitude': -157.8168,
#  'id': 1,
#  'latitude': 21.2716,
#  'station': 'USC00519397',
#  'elevation': 3.0}

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results

# First Step in getting last 12 months of data. 
last_data_point = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
print("The latest date was " + str(last_data_point) + ".")
# Out:
# The latest date was ('2017-08-23',).

# %%
# Second Step in getting last 12 months of data. 
### If you remove '.limit(10)' you can see the full 12 months. I am simply saving scroll time.
last_twelve_months = session.query(Measurement.date, Measurement.prcp).\
filter(Measurement.date >= '2016-08-23').\
    order_by(Measurement.date).all()
last_twelve_months
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-23', 0.15),
#  ('2016-08-23', 0.05),
#  ('2016-08-23', None),
#  ('2016-08-23', 0.02),
#  ('2016-08-23', 1.79),
#  ('2016-08-23', 0.7),
#  ('2016-08-24', 0.08),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 2.28),
#  ('2016-08-24', None),
#  ('2016-08-24', 1.22),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 1.45),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.21),
#  ('2016-08-25', 0.06),
#  ('2016-08-25', 0.11),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.03),
#  ('2016-08-26', 0.02),
#  ('2016-08-26', 0.04),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.01),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.18),
#  ('2016-08-27', 0.02),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.12),
#  ('2016-08-27', None),
#  ('2016-08-28', 0.01),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.6),
#  ('2016-08-28', 2.07),
#  ('2016-08-29', 0.0),
#  ('2016-08-29', 0.17),
#  ('2016-08-29', 0.04),
#  ('2016-08-29', None),
#  ('2016-08-29', 0.0),
#  ('2016-08-29', 0.35),
#  ('2016-08-29', 0.9),
#  ('2016-08-30', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-30', 0.02),
#  ('2016-08-30', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-30', 0.05),
#  ('2016-08-31', 0.13),
#  ('2016-08-31', 0.1),
#  ('2016-08-31', None),
#  ('2016-08-31', None),
#  ('2016-08-31', 0.25),
#  ('2016-08-31', 0.24),
#  ('2016-08-31', 2.46),
#  ('2016-09-01', 0.0),
#  ('2016-09-01', 0.0),
#  ('2016-09-01', 0.0),
#  ('2016-09-01', None),
#  ('2016-09-01', 0.02),
#  ('2016-09-01', 0.01),
#  ('2016-09-02', 0.0),
#  ('2016-09-02', 0.02),
#  ('2016-09-02', 0.19),
#  ('2016-09-02', None),
#  ('2016-09-02', None),
#  ('2016-09-02', 0.01),
#  ('2016-09-02', 0.03),
#  ('2016-09-03', 0.0),
#  ('2016-09-03', 0.07),
#  ('2016-09-03', 0.08),
#  ('2016-09-03', 0.12),
#  ('2016-09-03', 1.0),
#  ('2016-09-04', 0.03),
#  ('2016-09-04', 0.03),
#  ('2016-09-04', 0.74),
#  ('2016-09-04', 0.14),
#  ('2016-09-04', 0.44),
#  ('2016-09-05', None),
#  ('2016-09-05', 0.11),
#  ('2016-09-05', None),
#  ('2016-09-05', 0.02),
#  ('2016-09-05', 0.03),
#  ('2016-09-05', 0.18),
#  ('2016-09-06', None),
#  ('2016-09-06', 0.05),
#  ('2016-09-06', 0.04),
#  ('2016-09-06', 0.03),
#  ('2016-09-06', 0.11),
#  ('2016-09-06', 1.0),
#  ('2016-09-07', 0.05),
#  ('2016-09-07', 0.1),
#  ('2016-09-07', 0.23),
#  ('2016-09-07', 0.11),
#  ('2016-09-07', 0.16),
#  ('2016-09-07', 1.35),
#  ('2016-09-08', 0.0),
#  ('2016-09-08', 0.22),
#  ('2016-09-08', 0.01),
#  ('2016-09-08', None),
#  ('2016-09-08', 0.01),
#  ('2016-09-08', 0.07),
#  ('2016-09-08', 0.15),
#  ('2016-09-09', 0.03),
#  ('2016-09-09', 0.01),
#  ('2016-09-09', 0.29),
#  ('2016-09-09', None),
#  ('2016-09-09', 0.23),
#  ('2016-09-09', 0.16),
#  ('2016-09-09', 0.35),
#  ('2016-09-10', 0.0),
#  ('2016-09-10', 0.01),
#  ('2016-09-10', 0.14),
#  ('2016-09-10', 0.09),
#  ('2016-09-10', 1.16),
#  ('2016-09-11', 0.05),
#  ('2016-09-11', 0.18),
#  ('2016-09-11', 0.12),
#  ('2016-09-11', 0.3),
#  ('2016-09-11', 0.6),
#  ('2016-09-12', 0.0),
#  ('2016-09-12', 0.04),
#  ('2016-09-12', None),
#  ('2016-09-12', None),
#  ('2016-09-12', 0.15),
#  ('2016-09-12', 0.31),
#  ('2016-09-12', 1.04),
#  ('2016-09-13', 0.02),
#  ('2016-09-13', 0.37),
#  ('2016-09-13', 0.32),
#  ('2016-09-13', None),
#  ('2016-09-13', 0.46),
#  ('2016-09-13', 0.34),
#  ('2016-09-13', 1.2),
#  ('2016-09-14', 1.32),
#  ('2016-09-14', 0.9),
#  ('2016-09-14', 1.84),
#  ('2016-09-14', None),
#  ('2016-09-14', 1.19),
#  ('2016-09-14', 2.33),
#  ('2016-09-14', 6.7),
#  ('2016-09-15', 0.42),
#  ('2016-09-15', 0.12),
#  ('2016-09-15', 0.07),
#  ('2016-09-15', None),
#  ('2016-09-15', 0.17),
#  ('2016-09-15', 0.83),
#  ('2016-09-15', 3.35),
#  ('2016-09-16', 0.06),
#  ('2016-09-16', 0.01),
#  ('2016-09-16', 0.07),
#  ('2016-09-16', 0.0),
#  ('2016-09-16', 0.01),
#  ('2016-09-16', 0.06),
#  ('2016-09-16', 0.61),
#  ('2016-09-17', 0.05),
#  ('2016-09-17', 0.04),
#  ('2016-09-17', 0.0),
#  ('2016-09-17', 0.36),
#  ('2016-09-17', 0.23),
#  ('2016-09-18', 0.0),
#  ('2016-09-18', 0.0),
#  ('2016-09-18', 0.04),
#  ('2016-09-18', 0.07),
#  ('2016-09-18', 0.42),
#  ('2016-09-19', 0.0),
#  ('2016-09-19', 0.01),
#  ('2016-09-19', None),
#  ('2016-09-19', None),
#  ('2016-09-19', 0.05),
#  ('2016-09-19', 0.01),
#  ('2016-09-19', 0.25),
#  ('2016-09-20', 0.0),
#  ('2016-09-20', 0.09),
#  ('2016-09-20', 0.25),
#  ('2016-09-20', 0.0),
#  ('2016-09-20', 0.04),
#  ('2016-09-20', 0.22),
#  ('2016-09-20', 0.43),
#  ('2016-09-21', 0.0),
#  ('2016-09-21', 0.06),
#  ('2016-09-21', 0.02),
#  ('2016-09-21', 0.0),
#  ('2016-09-21', 0.07),
#  ('2016-09-21', 1.02),
#  ('2016-09-22', 0.02),
#  ('2016-09-22', 0.09),
#  ('2016-09-22', 0.17),
#  ('2016-09-22', 0.06),
#  ('2016-09-22', 0.01),
#  ('2016-09-22', 0.34),
#  ('2016-09-22', 0.75),
#  ('2016-09-23', 0.0),
#  ('2016-09-23', 0.15),
#  ('2016-09-23', 0.15),
#  ('2016-09-23', 0.0),
#  ('2016-09-23', 0.0),
#  ('2016-09-23', 0.94),
#  ('2016-09-23', 0.33),
#  ('2016-09-24', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-24', 0.01),
#  ('2016-09-24', 0.27),
#  ('2016-09-25', 0.0),
#  ('2016-09-25', 0.02),
#  ('2016-09-25', 0.0),
#  ('2016-09-25', 0.0),
#  ('2016-09-25', 0.03),
#  ('2016-09-25', 0.04),
#  ('2016-09-26', 0.06),
#  ('2016-09-26', 0.06),
#  ('2016-09-26', 0.02),
#  ('2016-09-26', None),
#  ('2016-09-26', 0.34),
#  ('2016-09-26', 0.17),
#  ('2016-09-26', 1.02),
#  ('2016-09-27', 0.02),
#  ('2016-09-27', 0.12),
#  ('2016-09-27', 0.0),
#  ('2016-09-27', 0.05),
#  ('2016-09-27', 0.17),
#  ('2016-09-27', 1.0),
#  ('2016-09-28', 0.0),
#  ('2016-09-28', 0.08),
#  ('2016-09-28', 0.0),
#  ('2016-09-28', 0.0),
#  ('2016-09-28', 0.0),
#  ('2016-09-28', 0.0),
#  ('2016-09-28', 0.05),
#  ('2016-09-29', 0.0),
#  ('2016-09-29', 0.49),
#  ('2016-09-29', 0.2),
#  ('2016-09-29', 0.04),
#  ('2016-09-29', 0.18),
#  ('2016-09-29', 0.59),
#  ('2016-09-29', 1.49),
#  ('2016-09-30', 0.0),
#  ('2016-09-30', 0.31),
#  ('2016-09-30', 0.06),
#  ('2016-09-30', None),
#  ('2016-09-30', 0.15),
#  ('2016-09-30', 0.25),
#  ('2016-09-30', 0.38),
#  ('2016-10-01', 0.0),
#  ('2016-10-01', 0.14),
#  ('2016-10-01', 0.08),
#  ('2016-10-01', 0.07),
#  ('2016-10-01', 0.14),
#  ('2016-10-01', 1.02),
#  ('2016-10-02', 0.0),
#  ('2016-10-02', 0.02),
#  ('2016-10-02', 0.03),
#  ('2016-10-02', 0.0),
#  ('2016-10-02', 0.06),
#  ('2016-10-02', 0.61),
#  ('2016-10-03', 0.0),
#  ('2016-10-03', 0.04),
#  ('2016-10-03', 0.03),
#  ('2016-10-03', None),
#  ('2016-10-03', 0.0),
#  ('2016-10-03', 0.16),
#  ('2016-10-03', 0.46),
#  ('2016-10-04', 0.0),
#  ('2016-10-04', 0.0),
#  ('2016-10-04', 0.0),
#  ('2016-10-04', None),
#  ('2016-10-04', 0.0),
#  ('2016-10-04', 0.03),
#  ('2016-10-04', 3.46),
#  ('2016-10-05', 0.0),
#  ('2016-10-05', 0.0),
#  ('2016-10-05', 0.0),
#  ('2016-10-05', None),
#  ('2016-10-05', 0.0),
#  ('2016-10-05', 0.01),
#  ('2016-10-05', 0.81),
#  ('2016-10-06', 0.0),
#  ('2016-10-06', 0.05),
#  ('2016-10-06', 0.0),
#  ('2016-10-06', 0.07),
#  ('2016-10-06', 0.0),
#  ('2016-10-06', 0.0),
#  ('2016-10-06', 0.04),
#  ('2016-10-07', 0.0),
#  ('2016-10-07', 0.0),
#  ('2016-10-07', 0.0),
#  ('2016-10-07', None),
#  ('2016-10-07', 0.0),
#  ('2016-10-07', 0.0),
#  ('2016-10-07', 0.01),
#  ('2016-10-08', 0.0),
#  ('2016-10-08', 0.0),
#  ('2016-10-08', 0.0),
#  ('2016-10-08', 0.0),
#  ('2016-10-08', 0.04),
#  ('2016-10-09', 0.0),
#  ('2016-10-09', 0.0),
#  ('2016-10-09', 0.0),
#  ('2016-10-09', 0.0),
#  ('2016-10-09', 0.0),
#  ('2016-10-10', 0.0),
#  ('2016-10-10', 0.0),
#  ('2016-10-10', None),
#  ('2016-10-10', 0.0),
#  ('2016-10-10', 0.0),
#  ('2016-10-10', 0.0),
#  ('2016-10-11', 0.0),
#  ('2016-10-11', 0.02),
#  ('2016-10-11', 0.04),
#  ('2016-10-11', None),
#  ('2016-10-11', 0.0),
#  ('2016-10-11', 0.28),
#  ('2016-10-11', 0.35),
#  ('2016-10-12', 0.0),
#  ('2016-10-12', 0.03),
#  ('2016-10-12', 0.0),
#  ('2016-10-12', 0.0),
#  ('2016-10-12', 0.03),
#  ('2016-10-12', 0.02),
#  ('2016-10-13', 0.0),
#  ('2016-10-13', 0.0),
#  ('2016-10-13', 0.02),
#  ('2016-10-13', None),
#  ('2016-10-13', 0.0),
#  ('2016-10-13', 0.0),
#  ('2016-10-13', 0.06),
#  ('2016-10-14', 0.0),
#  ('2016-10-14', 0.0),
#  ('2016-10-14', 0.0),
#  ('2016-10-14', 0.0),
#  ('2016-10-14', 0.0),
#  ('2016-10-14', 0.0),
#  ('2016-10-15', 0.0),
#  ('2016-10-15', 0.0),
#  ('2016-10-15', 0.02),
#  ('2016-10-15', 0.0),
#  ('2016-10-15', 0.04),
#  ('2016-10-15', 0.33),
#  ('2016-10-16', 0.0),
#  ('2016-10-16', 0.0),
#  ('2016-10-16', 0.0),
#  ('2016-10-16', 0.0),
#  ('2016-10-16', 0.0),
#  ('2016-10-17', 0.01),
#  ('2016-10-17', 0.03),
#  ('2016-10-17', None),
#  ('2016-10-17', None),
#  ('2016-10-17', 0.12),
#  ('2016-10-17', 0.01),
#  ('2016-10-17', 0.38),
#  ('2016-10-18', 0.0),
#  ('2016-10-18', 0.05),
#  ('2016-10-18', 0.03),
#  ('2016-10-18', None),
#  ('2016-10-18', 0.02),
#  ('2016-10-18', 0.02),
#  ('2016-10-18', 0.48),
#  ('2016-10-19', 0.0),
#  ('2016-10-19', 0.06),
#  ('2016-10-19', 0.0),
#  ('2016-10-19', None),
#  ('2016-10-19', 0.0),
#  ('2016-10-19', 0.11),
#  ('2016-10-19', 0.0),
#  ('2016-10-20', 0.0),
#  ('2016-10-20', 0.0),
#  ('2016-10-20', 0.01),
#  ('2016-10-20', None),
#  ('2016-10-20', 0.0),
#  ('2016-10-20', 1.0),
#  ('2016-10-21', 0.05),
#  ('2016-10-21', 0.15),
#  ('2016-10-21', 0.03),
#  ('2016-10-21', None),
#  ('2016-10-21', None),
#  ('2016-10-21', 0.0),
#  ('2016-10-21', 0.09),
#  ('2016-10-22', 0.15),
#  ('2016-10-22', 0.1),
#  ('2016-10-22', 0.0),
#  ('2016-10-22', 0.15),
#  ('2016-10-22', 1.37),
#  ('2016-10-23', 0.01),
#  ('2016-10-23', 0.01),
#  ('2016-10-23', None),
#  ('2016-10-23', 0.0),
#  ('2016-10-23', 0.02),
#  ('2016-10-23', 0.24),
#  ('2016-10-24', 0.0),
#  ('2016-10-24', 0.0),
#  ('2016-10-24', 0.01),
#  ('2016-10-24', None),
#  ('2016-10-24', 0.0),
#  ('2016-10-24', 0.08),
#  ('2016-10-24', 0.7),
#  ('2016-10-25', 0.03),
#  ('2016-10-25', 0.04),
#  ('2016-10-25', 0.0),
#  ('2016-10-25', 0.4),
#  ('2016-10-25', 0.12),
#  ('2016-10-25', 0.11),
#  ('2016-10-25', 0.4),
#  ('2016-10-26', 0.0),
#  ('2016-10-26', 0.06),
#  ('2016-10-26', 0.2),
#  ('2016-10-26', 0.02),
#  ('2016-10-26', 0.01),
#  ('2016-10-26', 0.0),
#  ('2016-10-27', 0.0),
#  ('2016-10-27', 0.11),
#  ('2016-10-27', 0.2),
#  ('2016-10-27', None),
#  ('2016-10-27', 0.08),
#  ('2016-10-27', 0.22),
#  ('2016-10-27', 1.25),
#  ('2016-10-28', 0.0),
#  ('2016-10-28', 0.02),
#  ('2016-10-28', 0.07),
#  ('2016-10-28', None),
#  ('2016-10-28', 0.06),
#  ('2016-10-28', 0.05),
#  ('2016-10-28', 0.37),
#  ('2016-10-29', 0.0),
#  ('2016-10-29', 0.02),
#  ('2016-10-29', 0.26),
#  ('2016-10-29', 0.01),
#  ('2016-10-29', 0.1),
#  ('2016-10-29', 0.25),
#  ('2016-10-30', 0.24),
#  ('2016-10-30', 0.1),
#  ('2016-10-30', 0.14),
#  ('2016-10-30', 0.0),
#  ('2016-10-30', 0.16),
#  ('2016-10-30', 0.95),
#  ('2016-10-31', 0.03),
#  ('2016-10-31', 0.03),
#  ('2016-10-31', 0.0),
#  ('2016-10-31', None),
#  ('2016-10-31', 0.13),
#  ('2016-10-31', 0.07),
#  ('2016-10-31', 1.35),
#  ('2016-11-01', 0.0),
#  ('2016-11-01', 0.01),
#  ('2016-11-01', 0.0),
#  ('2016-11-01', 0.01),
#  ('2016-11-01', 0.1),
#  ('2016-11-01', 0.09),
#  ('2016-11-02', 0.0),
#  ('2016-11-02', 0.0),
#  ('2016-11-02', 0.0),
#  ('2016-11-02', 0.0),
#  ('2016-11-02', 0.0),
#  ('2016-11-02', 0.04),
#  ('2016-11-03', 0.0),
#  ('2016-11-03', 0.0),
#  ('2016-11-03', 0.0),
#  ('2016-11-03', 0.0),
#  ('2016-11-03', 0.0),
#  ('2016-11-03', 0.02),
#  ('2016-11-04', 0.0),
#  ('2016-11-04', 0.0),
#  ('2016-11-04', 0.0),
#  ('2016-11-04', None),
#  ('2016-11-04', 0.0),
#  ('2016-11-04', 0.0),
#  ('2016-11-04', 0.06),
#  ('2016-11-05', 0.0),
#  ('2016-11-05', 0.02),
#  ('2016-11-05', 0.0),
#  ('2016-11-05', 0.02),
#  ('2016-11-05', 0.03),
#  ('2016-11-05', 0.38),
#  ('2016-11-06', 0.0),
#  ('2016-11-06', 0.02),
#  ('2016-11-06', 0.0),
#  ('2016-11-06', 0.0),
#  ('2016-11-06', 0.01),
#  ('2016-11-06', 0.05),
#  ('2016-11-07', 0.0),
#  ('2016-11-07', 0.0),
#  ('2016-11-07', 0.13),
#  ('2016-11-07', None),
#  ('2016-11-07', 0.0),
#  ('2016-11-07', 0.0),
#  ('2016-11-07', 0.05),
#  ('2016-11-08', 0.07),
#  ('2016-11-08', 0.14),
#  ('2016-11-08', 0.02),
#  ('2016-11-08', 0.15),
#  ('2016-11-08', 0.21),
#  ('2016-11-08', 0.53),
#  ('2016-11-09', 0.0),
#  ('2016-11-09', 0.08),
#  ('2016-11-09', 0.17),
#  ('2016-11-09', 0.0),
#  ('2016-11-09', 0.0),
#  ('2016-11-09', 0.11),
#  ('2016-11-09', 0.04),
#  ('2016-11-10', 0.0),
#  ('2016-11-10', 0.0),
#  ('2016-11-10', 0.0),
#  ('2016-11-10', 0.0),
#  ('2016-11-10', 0.0),
#  ('2016-11-10', 0.01),
#  ('2016-11-11', 0.0),
#  ('2016-11-11', 0.0),
#  ('2016-11-11', 0.0),
#  ('2016-11-11', 0.0),
#  ('2016-11-11', 0.0),
#  ('2016-11-11', 0.0),
#  ('2016-11-12', 0.0),
#  ('2016-11-12', 0.0),
#  ('2016-11-12', 0.0),
#  ('2016-11-12', 0.0),
#  ('2016-11-12', 0.0),
#  ('2016-11-12', 0.0),
#  ('2016-11-13', 0.0),
#  ('2016-11-13', 0.0),
#  ('2016-11-13', 0.0),
#  ('2016-11-13', 0.0),
#  ('2016-11-13', 0.0),
#  ('2016-11-13', 0.0),
#  ('2016-11-14', 0.0),
#  ('2016-11-14', 0.06),
#  ('2016-11-14', 0.05),
#  ('2016-11-14', 0.02),
#  ('2016-11-14', 0.0),
#  ('2016-11-14', 0.0),
#  ('2016-11-14', 0.02),
#  ('2016-11-15', 0.0),
#  ('2016-11-15', 0.0),
#  ('2016-11-15', 0.0),
#  ('2016-11-15', None),
#  ('2016-11-15', 0.0),
#  ('2016-11-15', 0.0),
#  ('2016-11-15', 0.05),
#  ('2016-11-16', 0.0),
#  ('2016-11-16', 0.14),
#  ('2016-11-16', 0.18),
#  ('2016-11-16', None),
#  ('2016-11-16', 0.07),
#  ('2016-11-16', 0.24),
#  ('2016-11-16', 0.91),
#  ('2016-11-17', 0.0),
#  ('2016-11-17', 0.03),
#  ('2016-11-17', 0.0),
#  ('2016-11-17', None),
#  ('2016-11-17', 0.0),
#  ('2016-11-17', 0.01),
#  ('2016-11-17', 0.02),
#  ('2016-11-18', 0.0),
#  ('2016-11-18', 0.01),
#  ('2016-11-18', None),
#  ('2016-11-18', 0.02),
#  ('2016-11-18', 0.0),
#  ('2016-11-19', 0.03),
#  ('2016-11-19', 0.11),
#  ('2016-11-19', 0.13),
#  ('2016-11-19', 0.11),
#  ('2016-11-20', 0.05),
#  ('2016-11-20', 0.11),
#  ('2016-11-20', 0.4),
#  ('2016-11-20', 0.39),
#  ('2016-11-20', None),
#  ('2016-11-21', 0.01),
#  ('2016-11-21', 0.02),
#  ('2016-11-21', None),
#  ('2016-11-21', 0.07),
#  ('2016-11-21', 0.11),
#  ('2016-11-21', 2.87),
#  ('2016-11-22', 0.13),
#  ('2016-11-22', 0.41),
#  ('2016-11-22', None),
#  ('2016-11-22', None),
#  ('2016-11-22', 0.31),
#  ('2016-11-22', 2.05),
#  ('2016-11-22', 2.11),
#  ('2016-11-23', 0.14),
#  ('2016-11-23', 0.03),
#  ('2016-11-23', None),
#  ('2016-11-23', 0.03),
#  ('2016-11-23', 0.25),
#  ('2016-11-23', 0.22),
#  ('2016-11-24', 0.05),
#  ('2016-11-24', 0.2),
#  ('2016-11-24', 0.21),
#  ('2016-11-24', 0.3),
#  ('2016-11-24', 0.72),
#  ('2016-11-25', 0.05),
#  ('2016-11-25', 0.05),
#  ('2016-11-25', None),
#  ('2016-11-25', 0.11),
#  ('2016-11-25', 0.08),
#  ('2016-11-25', 1.03),
#  ('2016-11-26', 0.05),
#  ('2016-11-26', 0.05),
#  ('2016-11-26', 0.02),
#  ('2016-11-26', 0.03),
#  ('2016-11-26', 0.06),
#  ('2016-11-26', 0.3),
#  ('2016-11-27', 0.0),
#  ('2016-11-27', 0.06),
#  ('2016-11-27', 0.03),
#  ('2016-11-27', 0.0),
#  ('2016-11-27', 0.17),
#  ('2016-11-27', 0.29),
#  ('2016-11-28', 0.01),
#  ('2016-11-28', 0.02),
#  ('2016-11-28', 0.0),
#  ('2016-11-28', None),
#  ('2016-11-28', 0.0),
#  ('2016-11-28', 0.0),
#  ('2016-11-28', 0.69),
#  ('2016-11-29', 0.0),
#  ('2016-11-29', 0.04),
#  ('2016-11-29', 0.04),
#  ('2016-11-29', None),
#  ('2016-11-29', 0.06),
#  ('2016-11-29', 0.09),
#  ('2016-11-29', 0.2),
#  ('2016-11-30', 0.14),
#  ('2016-11-30', 0.05),
#  ('2016-11-30', 0.03),
#  ('2016-11-30', None),
#  ('2016-11-30', 0.0),
#  ('2016-11-30', 0.05),
#  ('2016-11-30', 0.79),
#  ('2016-12-01', 0.12),
#  ('2016-12-01', 0.33),
#  ('2016-12-01', 0.07),
#  ('2016-12-01', None),
#  ('2016-12-01', 0.16),
#  ('2016-12-01', 0.37),
#  ('2016-12-01', 0.72),
#  ('2016-12-02', 0.03),
#  ('2016-12-02', 0.3),
#  ('2016-12-02', 0.4),
#  ('2016-12-02', None),
#  ('2016-12-02', 0.01),
#  ('2016-12-02', 0.35),
#  ('2016-12-02', 1.27),
#  ('2016-12-03', 0.0),
#  ('2016-12-03', 0.04),
#  ('2016-12-03', 0.26),
#  ('2016-12-03', 0.02),
#  ('2016-12-03', 0.77),
#  ('2016-12-03', 1.62),
#  ('2016-12-04', 0.03),
#  ('2016-12-04', 0.1),
#  ('2016-12-04', 0.0),
#  ('2016-12-04', 0.32),
#  ('2016-12-04', 0.04),
#  ('2016-12-04', 0.31),
#  ('2016-12-05', 0.43),
#  ('2016-12-05', 0.34),
#  ('2016-12-05', 0.2),
#  ('2016-12-05', None),
#  ('2016-12-05', 0.45),
#  ('2016-12-05', 0.22),
#  ('2016-12-05', 1.6),
#  ('2016-12-06', 0.02),
#  ('2016-12-06', 0.02),
#  ('2016-12-06', None),
#  ('2016-12-06', 0.0),
#  ('2016-12-06', 0.0),
#  ('2016-12-06', 0.0),
#  ('2016-12-07', 0.0),
#  ('2016-12-07', 0.17),
#  ('2016-12-07', None),
#  ('2016-12-07', None),
#  ('2016-12-07', 0.07),
#  ('2016-12-07', 0.12),
#  ('2016-12-07', 0.02),
#  ('2016-12-08', 0.03),
#  ('2016-12-08', 0.03),
#  ('2016-12-08', 0.02),
#  ('2016-12-08', 0.27),
#  ('2016-12-08', 0.01),
#  ('2016-12-08', 0.07),
#  ('2016-12-08', 0.03),
#  ('2016-12-09', 0.52),
#  ('2016-12-09', 0.34),
#  ('2016-12-09', 0.26),
#  ('2016-12-09', None),
#  ('2016-12-09', 0.31),
#  ('2016-12-09', 0.42),
#  ('2016-12-10', 0.05),
#  ('2016-12-10', 0.02),
#  ('2016-12-10', 0.0),
#  ('2016-12-10', None),
#  ('2016-12-10', 0.02),
#  ('2016-12-10', 0.04),
#  ('2016-12-11', 0.04),
#  ('2016-12-11', 0.02),
#  ('2016-12-11', 0.06),
#  ('2016-12-11', 0.0),
#  ('2016-12-11', 0.13),
#  ('2016-12-12', 0.01),
#  ('2016-12-12', 0.01),
#  ('2016-12-12', None),
#  ('2016-12-12', 0.02),
#  ('2016-12-12', 0.0),
#  ('2016-12-12', 0.0),
#  ('2016-12-12', 0.01),
#  ('2016-12-13', 0.05),
#  ('2016-12-13', 0.1),
#  ('2016-12-13', 0.34),
#  ('2016-12-13', None),
#  ('2016-12-13', 0.15),
#  ('2016-12-13', 0.04),
#  ('2016-12-13', 0.09),
#  ('2016-12-14', 0.03),
#  ('2016-12-14', 0.05),
#  ('2016-12-14', 0.12),
#  ('2016-12-14', None),
#  ('2016-12-14', 0.05),
#  ('2016-12-14', 0.92),
#  ('2016-12-14', 0.33),
#  ('2016-12-15', 0.0),
#  ('2016-12-15', 0.02),
#  ('2016-12-15', 0.07),
#  ('2016-12-15', None),
#  ('2016-12-15', 0.0),
#  ('2016-12-15', 0.14),
#  ('2016-12-15', 0.03),
#  ('2016-12-16', 0.0),
#  ('2016-12-16', 0.01),
#  ('2016-12-16', 0.0),
#  ('2016-12-16', None),
#  ('2016-12-16', 0.0),
#  ('2016-12-16', 0.03),
#  ('2016-12-16', 0.0),
#  ('2016-12-17', 0.01),
#  ('2016-12-17', 0.11),
#  ('2016-12-17', 0.0),
#  ('2016-12-17', 0.16),
#  ('2016-12-17', 0.07),
#  ('2016-12-18', 0.13),
#  ('2016-12-18', 0.29),
#  ('2016-12-18', 0.04),
#  ('2016-12-18', 0.27),
#  ('2016-12-18', 0.16),
#  ('2016-12-18', None),
#  ('2016-12-19', 0.01),
#  ('2016-12-19', 0.21),
#  ('2016-12-19', 0.0),
#  ('2016-12-19', None),
#  ('2016-12-19', 0.02),
#  ('2016-12-19', 0.03),
#  ('2016-12-19', 0.15),
#  ('2016-12-20', 0.0),
#  ('2016-12-20', 0.02),
#  ('2016-12-20', 0.0),
#  ('2016-12-20', None),
#  ('2016-12-20', 0.01),
#  ('2016-12-20', 0.0),
#  ('2016-12-20', 0.0),
#  ('2016-12-21', 0.0),
#  ('2016-12-21', 0.03),
#  ('2016-12-21', 0.09),
#  ('2016-12-21', 0.06),
#  ('2016-12-21', 0.06),
#  ('2016-12-21', 0.11),
#  ('2016-12-21', 0.55),
#  ('2016-12-22', 0.01),
#  ('2016-12-22', 0.17),
#  ('2016-12-22', 0.05),
#  ('2016-12-22', None),
#  ('2016-12-22', 0.14),
#  ('2016-12-22', 0.86),
#  ('2016-12-22', 1.24),
#  ('2016-12-23', 0.01),
#  ('2016-12-23', 0.1),
#  ('2016-12-23', 0.03),
#  ('2016-12-23', None),
#  ('2016-12-23', 0.02),
#  ('2016-12-23', 0.24),
#  ('2016-12-23', 0.83),
#  ('2016-12-24', 0.01),
#  ('2016-12-24', 0.14),
#  ('2016-12-24', 0.13),
#  ('2016-12-24', 0.06),
#  ('2016-12-24', 0.2),
#  ('2016-12-24', 1.08),
#  ('2016-12-25', 0.0),
#  ('2016-12-25', 0.03),
#  ('2016-12-25', 0.0),
#  ('2016-12-25', 0.02),
#  ('2016-12-25', 0.38),
#  ('2016-12-26', 0.02),
#  ('2016-12-26', 0.26),
#  ('2016-12-26', None),
#  ('2016-12-26', 0.06),
#  ('2016-12-26', 0.22),
#  ('2016-12-26', 1.48),
#  ('2016-12-27', 0.0),
#  ('2016-12-27', 0.03),
#  ('2016-12-27', 0.02),
#  ('2016-12-27', 0.0),
#  ('2016-12-27', 0.05),
#  ('2016-12-27', 0.14),
#  ('2016-12-28', 0.02),
#  ('2016-12-28', 0.09),
#  ('2016-12-28', 0.01),
#  ('2016-12-28', None),
#  ('2016-12-28', 0.06),
#  ('2016-12-28', 0.09),
#  ('2016-12-28', 0.14),
#  ('2016-12-29', 0.04),
#  ('2016-12-29', 0.18),
#  ('2016-12-29', 0.56),
#  ('2016-12-29', None),
#  ('2016-12-29', 0.05),
#  ('2016-12-29', 0.52),
#  ('2016-12-29', 1.03),
#  ('2016-12-30', 0.12),
#  ('2016-12-30', 0.21),
#  ('2016-12-30', 0.29),
#  ('2016-12-30', None),
#  ('2016-12-30', 0.07),
#  ('2016-12-30', 0.29),
#  ('2016-12-30', 2.37),
#  ('2016-12-31', 0.01),
#  ('2016-12-31', 0.62),
#  ('2016-12-31', 0.36),
#  ('2016-12-31', 0.25),
#  ('2016-12-31', 0.9),
#  ('2017-01-01', 0.0),
#  ('2017-01-01', 0.29),
#  ('2017-01-01', 0.0),
#  ('2017-01-01', None),
#  ('2017-01-01', 0.03),
#  ('2017-01-01', 0.03),
#  ('2017-01-02', 0.0),
#  ('2017-01-02', 0.0),
#  ('2017-01-02', 0.01),
#  ('2017-01-02', 0.01),
#  ('2017-01-02', 0.0),
#  ('2017-01-03', 0.0),
#  ('2017-01-03', 0.0),
#  ('2017-01-03', 0.0),
#  ('2017-01-03', None),
#  ('2017-01-03', 0.0),
#  ('2017-01-03', 0.0),
#  ('2017-01-04', 0.0),
#  ('2017-01-04', 0.0),
#  ('2017-01-04', 0.0),
#  ('2017-01-04', 0.18),
#  ('2017-01-04', 0.0),
#  ('2017-01-04', 0.0),
#  ('2017-01-05', 0.0),
#  ('2017-01-05', 0.0),
#  ('2017-01-05', 0.0),
#  ('2017-01-05', 0.42),
#  ('2017-01-05', 0.06),
#  ('2017-01-05', 0.47),
#  ('2017-01-06', 0.0),
#  ('2017-01-06', 0.0),
#  ('2017-01-06', 0.59),
#  ('2017-01-06', 0.01),
#  ('2017-01-06', 0.1),
#  ('2017-01-06', 0.1),
#  ('2017-01-07', 0.0),
#  ('2017-01-07', 0.06),
#  ('2017-01-07', 0.0),
#  ('2017-01-07', 0.0),
#  ('2017-01-07', 0.0),
#  ('2017-01-07', 0.0),
#  ('2017-01-08', 0.0),
#  ('2017-01-08', 0.0),
#  ('2017-01-08', 0.03),
#  ('2017-01-08', 0.0),
#  ('2017-01-08', 0.0),
#  ('2017-01-08', 0.03),
#  ('2017-01-09', 0.0),
#  ('2017-01-09', 0.0),
#  ('2017-01-09', 0.0),
#  ('2017-01-09', None),
#  ('2017-01-09', 0.0),
#  ('2017-01-09', 0.0),
#  ('2017-01-09', 0.0),
#  ('2017-01-10', 0.0),
#  ('2017-01-10', 0.0),
#  ('2017-01-10', 0.0),
#  ('2017-01-10', None),
#  ('2017-01-10', 0.0),
#  ('2017-01-10', 0.0),
#  ('2017-01-10', 0.0),
#  ('2017-01-11', 0.0),
#  ('2017-01-11', 0.0),
#  ('2017-01-11', 0.0),
#  ('2017-01-11', None),
#  ('2017-01-11', 0.0),
#  ('2017-01-11', 0.0),
#  ('2017-01-12', 0.0),
#  ('2017-01-12', 0.0),
#  ('2017-01-12', None),
#  ('2017-01-12', None),
#  ('2017-01-12', 0.0),
#  ('2017-01-12', 0.0),
#  ('2017-01-13', 0.0),
#  ('2017-01-13', 0.0),
#  ('2017-01-13', None),
#  ('2017-01-13', None),
#  ('2017-01-13', 0.0),
#  ('2017-01-13', 0.0),
#  ('2017-01-14', 0.0),
#  ('2017-01-14', 0.0),
#  ('2017-01-14', 0.0),
#  ('2017-01-14', 0.01),
#  ('2017-01-14', 0.0),
#  ('2017-01-15', 0.0),
#  ('2017-01-15', 0.0),
#  ('2017-01-15', None),
#  ('2017-01-15', 0.0),
#  ('2017-01-15', 0.01),
#  ('2017-01-16', 0.0),
#  ('2017-01-16', 0.0),
#  ('2017-01-16', None),
#  ('2017-01-16', 0.0),
#  ('2017-01-16', 0.0),
#  ('2017-01-16', 0.0),
#  ('2017-01-17', 0.0),
#  ('2017-01-17', 0.0),
#  ('2017-01-17', 0.0),
#  ('2017-01-17', 0.0),
#  ('2017-01-17', 0.0),
#  ('2017-01-17', 0.0),
#  ('2017-01-18', 0.0),
#  ('2017-01-18', 0.0),
#  ('2017-01-18', 0.0),
#  ('2017-01-18', 0.0),
#  ('2017-01-18', None),
#  ('2017-01-18', 0.0),
#  ('2017-01-18', 0.07),
#  ('2017-01-19', 0.0),
#  ('2017-01-19', 0.0),
#  ('2017-01-19', 0.0),
#  ('2017-01-19', None),
#  ('2017-01-19', 0.0),
#  ('2017-01-19', 0.02),
#  ('2017-01-19', 0.0),
#  ('2017-01-20', 0.0),
#  ('2017-01-20', 0.0),
#  ('2017-01-20', 0.0),
#  ('2017-01-20', None),
#  ('2017-01-20', 0.0),
#  ('2017-01-20', 0.0),
#  ('2017-01-20', 0.0),
#  ('2017-01-21', 0.0),
#  ('2017-01-21', 0.04),
#  ('2017-01-21', 0.02),
#  ('2017-01-21', 0.11),
#  ('2017-01-21', 0.03),
#  ('2017-01-21', 0.08),
#  ('2017-01-22', 0.16),
#  ('2017-01-22', 0.01),
#  ('2017-01-22', 0.04),
#  ('2017-01-22', 0.09),
#  ('2017-01-22', 0.72),
#  ('2017-01-23', 0.0),
#  ('2017-01-23', 0.08),
#  ('2017-01-23', None),
#  ('2017-01-23', None),
#  ('2017-01-23', 0.0),
#  ('2017-01-23', 0.01),
#  ('2017-01-23', 0.85),
#  ('2017-01-24', 0.04),
#  ('2017-01-24', 0.15),
#  ('2017-01-24', None),
#  ('2017-01-24', 0.08),
#  ('2017-01-24', 0.13),
#  ('2017-01-24', 1.85),
#  ('2017-01-25', 0.03),
#  ('2017-01-25', 0.12),
#  ('2017-01-25', None),
#  ('2017-01-25', None),
#  ('2017-01-25', 0.0),
#  ('2017-01-25', 0.79),
#  ('2017-01-25', 2.64),
#  ('2017-01-26', 0.0),
#  ('2017-01-26', 0.0),
#  ('2017-01-26', 0.01),
#  ('2017-01-26', 0.0),
#  ('2017-01-26', 0.0),
#  ('2017-01-26', 0.0),
#  ('2017-01-26', 0.1),
#  ('2017-01-27', 0.0),
#  ('2017-01-27', 0.0),
#  ('2017-01-27', 0.0),
#  ('2017-01-27', 0.0),
#  ('2017-01-27', 0.0),
#  ('2017-01-27', 0.03),
#  ('2017-01-27', 0.03),
#  ...]

# %%
# Calculate the date 1 year ago from the last data point in the database
one_year_ago_from_last_datapoint = session.query(Measurement.date).\
filter(Measurement.date == '2016-08-23').first()
print("One year ago was " + str(one_year_ago_from_last_datapoint) + ".")
# Out:
# One year ago was ('2016-08-23',).

# %%
# Perform a query to retrieve the data and precipitation scores

# Save the query results as a Pandas DataFrame and set the index to the date column
last_twelve_months_df = pd.DataFrame(last_twelve_months, 
                                     columns=["date", "precipitation"]).set_index("date")
last_twelve_months_df
# Sort the dataframe by date

# Use Pandas Plotting with Matplotlib to plot the data
x_values = last_twelve_months_df.index
y_values = last_twelve_months_df["precipitation"]

last_twelve_months_df.plot(rot = 45, alpha = 0.99, color = 'g', figsize = (10, 6), legend = True)
plt.title("Precipitation by Day from 2016-08-23 to 2017-08-23")
plt.ylabel("Rainfall (Inches)")
plt.xlabel("Dates")
plt.tight_layout()
plt.savefig('../Images/last_twelve_months_precipitation.png')
plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
summary_statistics_precipitation_data = last_twelve_months_df.describe()
summary_statistics_precipitation_data
# Out:
#        precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
# Design a query to show how many stations are available in this dataset?
number_of_stations_in_Measurement_dataset = session.query(Measurement.station).count()
print("There are " + str(number_of_stations_in_Measurement_dataset) + " available stations in the Measurement dataset.")
# Out:
# There are 19550 available stations in the Measurement dataset.

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
stats_of_most_active_stations_plural = session.query(Measurement.station, 
                                            func.count(Measurement.station),
                                            func.min(Measurement.tobs), 
                                            func.max(Measurement.tobs), 
                                            func.avg(Measurement.tobs)).\
                                    group_by(Measurement.station).\
                                    order_by(func.count(Measurement.station).desc()).all()
stats_of_most_active_stations_plural
# Out:
# [('USC00519281', 2772, 54.0, 85.0, 71.66378066378067),
#  ('USC00519397', 2724, 56.0, 87.0, 74.55323054331865),
#  ('USC00513117', 2709, 59.0, 85.0, 72.68918420081211),
#  ('USC00519523', 2669, 56.0, 85.0, 74.5436493068565),
#  ('USC00516128', 2612, 58.0, 84.0, 70.91500765696784),
#  ('USC00514830', 2202, 58.0, 85.0, 74.8732970027248),
#  ('USC00511918', 1979, 53.0, 87.0, 71.61596766043456),
#  ('USC00517948', 1372, 58.0, 87.0, 74.68440233236151),
#  ('USC00518838', 511, 58.0, 83.0, 72.72407045009784)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?
stats_of_most_active_station = session.query(Measurement.station, 
                                    func.count(Measurement.station),
                                    func.min(Measurement.tobs), 
                                    func.max(Measurement.tobs), 
                                    func.avg(Measurement.tobs)).\
                                    group_by(Measurement.station).\
                                    order_by(func.count(Measurement.station).desc()).first()
stats_of_most_active_station
# Out:
# ('USC00519281', 2772, 54.0, 85.0, 71.66378066378067)

# %%
# Choose the station with the highest number of temperature observations.
most_active_station = session.query(Measurement.station, 
                                    func.count(Measurement.tobs)).\
                                    group_by(Measurement.station).\
                                    order_by(func.count(Measurement.tobs).desc()).first()
most_active_station
# Out:
# ('USC00519281', 2772)

# %%
# Query the last 12 months of temperature observation data for this station
last_twelve_months_for_USC00519281 = session.query(Measurement.date, Measurement.station, Measurement.tobs).\
filter(Measurement.date >= '2016-08-23').\
filter(Measurement.station == most_active_station[0]).\
    group_by(Measurement.date).\
    order_by(Measurement.date.desc()).all()
last_twelve_months_for_USC00519281
# Out:
# [('2017-08-18', 'USC00519281', 79.0),
#  ('2017-08-17', 'USC00519281', 76.0),
#  ('2017-08-16', 'USC00519281', 76.0),
#  ('2017-08-15', 'USC00519281', 77.0),
#  ('2017-08-14', 'USC00519281', 77.0),
#  ('2017-08-13', 'USC00519281', 77.0),
#  ('2017-08-06', 'USC00519281', 83.0),
#  ('2017-08-05', 'USC00519281', 82.0),
#  ('2017-08-04', 'USC00519281', 77.0),
#  ('2017-07-31', 'USC00519281', 76.0),
#  ('2017-07-30', 'USC00519281', 81.0),
#  ('2017-07-29', 'USC00519281', 82.0),
#  ('2017-07-28', 'USC00519281', 81.0),
#  ('2017-07-27', 'USC00519281', 76.0),
#  ('2017-07-26', 'USC00519281', 75.0),
#  ('2017-07-25', 'USC00519281', 77.0),
#  ('2017-07-24', 'USC00519281', 75.0),
#  ('2017-07-23', 'USC00519281', 82.0),
#  ('2017-07-22', 'USC00519281', 77.0),
#  ('2017-07-21', 'USC00519281', 77.0),
#  ('2017-07-20', 'USC00519281', 77.0),
#  ('2017-07-19', 'USC00519281', 76.0),
#  ('2017-07-18', 'USC00519281', 76.0),
#  ('2017-07-17', 'USC00519281', 76.0),
#  ('2017-07-16', 'USC00519281', 80.0),
#  ('2017-07-15', 'USC00519281', 80.0),
#  ('2017-07-14', 'USC00519281', 76.0),
#  ('2017-07-13', 'USC00519281', 74.0),
#  ('2017-07-12', 'USC00519281', 74.0),
#  ('2017-07-11', 'USC00519281', 72.0),
#  ('2017-07-10', 'USC00519281', 69.0),
#  ('2017-07-09', 'USC00519281', 78.0),
#  ('2017-07-08', 'USC00519281', 78.0),
#  ('2017-07-07', 'USC00519281', 75.0),
#  ('2017-07-06', 'USC00519281', 74.0),
#  ('2017-07-05', 'USC00519281', 77.0),
#  ('2017-07-04', 'USC00519281', 78.0),
#  ('2017-07-03', 'USC00519281', 76.0),
#  ('2017-07-02', 'USC00519281', 81.0),
#  ('2017-07-01', 'USC00519281', 79.0),
#  ('2017-06-30', 'USC00519281', 76.0),
#  ('2017-06-29', 'USC00519281', 76.0),
#  ('2017-06-28', 'USC00519281', 77.0),
#  ('2017-06-27', 'USC00519281', 76.0),
#  ('2017-06-26', 'USC00519281', 73.0),
#  ('2017-06-25', 'USC00519281', 71.0),
#  ('2017-06-24', 'USC00519281', 77.0),
#  ('2017-06-23', 'USC00519281', 72.0),
#  ('2017-06-22', 'USC00519281', 72.0),
#  ('2017-06-21', 'USC00519281', 74.0),
#  ('2017-06-20', 'USC00519281', 72.0),
#  ('2017-06-19', 'USC00519281', 72.0),
#  ('2017-06-18', 'USC00519281', 75.0),
#  ('2017-06-17', 'USC00519281', 79.0),
#  ('2017-06-16', 'USC00519281', 73.0),
#  ('2017-06-15', 'USC00519281', 75.0),
#  ('2017-06-14', 'USC00519281', 74.0),
#  ('2017-06-13', 'USC00519281', 76.0),
#  ('2017-06-12', 'USC00519281', 74.0),
#  ('2017-06-11', 'USC00519281', 74.0),
#  ('2017-06-10', 'USC00519281', 74.0),
#  ('2017-06-09', 'USC00519281', 72.0),
#  ('2017-06-08', 'USC00519281', 75.0),
#  ('2017-06-07', 'USC00519281', 75.0),
#  ('2017-06-06', 'USC00519281', 75.0),
#  ('2017-06-05', 'USC00519281', 75.0),
#  ('2017-06-04', 'USC00519281', 77.0),
#  ('2017-06-03', 'USC00519281', 76.0),
#  ('2017-06-02', 'USC00519281', 76.0),
#  ('2017-06-01', 'USC00519281', 80.0),
#  ('2017-05-31', 'USC00519281', 75.0),
#  ('2017-05-30', 'USC00519281', 72.0),
#  ('2017-05-29', 'USC00519281', 74.0),
#  ('2017-05-28', 'USC00519281', 80.0),
#  ('2017-05-27', 'USC00519281', 74.0),
#  ('2017-05-26', 'USC00519281', 74.0),
#  ('2017-05-25', 'USC00519281', 74.0),
#  ('2017-05-24', 'USC00519281', 74.0),
#  ('2017-05-23', 'USC00519281', 71.0),
#  ('2017-05-22', 'USC00519281', 71.0),
#  ('2017-05-21', 'USC00519281', 74.0),
#  ('2017-05-20', 'USC00519281', 76.0),
#  ('2017-05-19', 'USC00519281', 68.0),
#  ('2017-05-18', 'USC00519281', 69.0),
#  ('2017-05-17', 'USC00519281', 74.0),
#  ('2017-05-16', 'USC00519281', 74.0),
#  ('2017-05-15', 'USC00519281', 74.0),
#  ('2017-05-14', 'USC00519281', 77.0),
#  ('2017-05-13', 'USC00519281', 76.0),
#  ('2017-05-12', 'USC00519281', 75.0),
#  ('2017-05-11', 'USC00519281', 70.0),
#  ('2017-05-10', 'USC00519281', 74.0),
#  ('2017-05-09', 'USC00519281', 67.0),
#  ('2017-05-08', 'USC00519281', 70.0),
#  ('2017-05-07', 'USC00519281', 75.0),
#  ('2017-05-06', 'USC00519281', 79.0),
#  ('2017-05-05', 'USC00519281', 70.0),
#  ('2017-05-04', 'USC00519281', 75.0),
#  ('2017-05-03', 'USC00519281', 70.0),
#  ('2017-05-02', 'USC00519281', 75.0),
#  ('2017-05-01', 'USC00519281', 65.0),
#  ('2017-04-30', 'USC00519281', 60.0),
#  ('2017-04-29', 'USC00519281', 72.0),
#  ('2017-04-28', 'USC00519281', 67.0),
#  ('2017-04-27', 'USC00519281', 70.0),
#  ('2017-04-26', 'USC00519281', 74.0),
#  ('2017-04-25', 'USC00519281', 72.0),
#  ('2017-04-24', 'USC00519281', 68.0),
#  ('2017-04-23', 'USC00519281', 76.0),
#  ('2017-04-22', 'USC00519281', 72.0),
#  ('2017-04-21', 'USC00519281', 69.0),
#  ('2017-04-20', 'USC00519281', 76.0),
#  ('2017-04-19', 'USC00519281', 67.0),
#  ('2017-04-18', 'USC00519281', 68.0),
#  ('2017-04-17', 'USC00519281', 67.0),
#  ('2017-04-16', 'USC00519281', 71.0),
#  ('2017-04-15', 'USC00519281', 78.0),
#  ('2017-04-14', 'USC00519281', 74.0),
#  ('2017-04-13', 'USC00519281', 69.0),
#  ('2017-04-12', 'USC00519281', 69.0),
#  ('2017-04-11', 'USC00519281', 70.0),
#  ('2017-04-10', 'USC00519281', 67.0),
#  ('2017-04-09', 'USC00519281', 78.0),
#  ('2017-04-08', 'USC00519281', 77.0),
#  ('2017-04-07', 'USC00519281', 74.0),
#  ('2017-04-06', 'USC00519281', 67.0),
#  ('2017-04-05', 'USC00519281', 71.0),
#  ('2017-04-04', 'USC00519281', 67.0),
#  ('2017-04-03', 'USC00519281', 70.0),
#  ('2017-04-02', 'USC00519281', 75.0),
#  ('2017-04-01', 'USC00519281', 74.0),
#  ('2017-03-31', 'USC00519281', 71.0),
#  ('2017-03-30', 'USC00519281', 73.0),
#  ('2017-03-29', 'USC00519281', 68.0),
#  ('2017-03-28', 'USC00519281', 74.0),
#  ('2017-03-27', 'USC00519281', 76.0),
#  ('2017-03-26', 'USC00519281', 77.0),
#  ('2017-03-25', 'USC00519281', 76.0),
#  ('2017-03-24', 'USC00519281', 71.0),
#  ('2017-03-23', 'USC00519281', 72.0),
#  ('2017-03-22', 'USC00519281', 73.0),
#  ('2017-03-21', 'USC00519281', 72.0),
#  ('2017-03-20', 'USC00519281', 69.0),
#  ('2017-03-19', 'USC00519281', 74.0),
#  ('2017-03-18', 'USC00519281', 65.0),
#  ('2017-03-17', 'USC00519281', 68.0),
#  ('2017-03-16', 'USC00519281', 66.0),
#  ('2017-03-15', 'USC00519281', 69.0),
#  ('2017-03-14', 'USC00519281', 67.0),
#  ('2017-03-13', 'USC00519281', 66.0),
#  ('2017-03-12', 'USC00519281', 69.0),
#  ('2017-03-11', 'USC00519281', 81.0),
#  ('2017-03-10', 'USC00519281', 66.0),
#  ('2017-03-09', 'USC00519281', 67.0),
#  ('2017-03-08', 'USC00519281', 64.0),
#  ('2017-03-07', 'USC00519281', 62.0),
#  ('2017-03-06', 'USC00519281', 67.0),
#  ('2017-03-05', 'USC00519281', 73.0),
#  ('2017-03-04', 'USC00519281', 77.0),
#  ('2017-03-03', 'USC00519281', 72.0),
#  ('2017-03-02', 'USC00519281', 73.0),
#  ('2017-03-01', 'USC00519281', 71.0),
#  ('2017-02-28', 'USC00519281', 72.0),
#  ('2017-02-27', 'USC00519281', 65.0),
#  ('2017-02-26', 'USC00519281', 67.0),
#  ('2017-02-25', 'USC00519281', 61.0),
#  ('2017-02-24', 'USC00519281', 69.0),
#  ('2017-02-23', 'USC00519281', 71.0),
#  ('2017-02-22', 'USC00519281', 71.0),
#  ('2017-02-21', 'USC00519281', 71.0),
#  ('2017-02-20', 'USC00519281', 70.0),
#  ('2017-02-19', 'USC00519281', 70.0),
#  ('2017-02-18', 'USC00519281', 74.0),
#  ('2017-02-17', 'USC00519281', 70.0),
#  ('2017-02-16', 'USC00519281', 65.0),
#  ('2017-02-15', 'USC00519281', 75.0),
#  ('2017-02-14', 'USC00519281', 79.0),
#  ('2017-02-13', 'USC00519281', 73.0),
#  ('2017-02-12', 'USC00519281', 70.0),
#  ('2017-02-11', 'USC00519281', 68.0),
#  ('2017-02-10', 'USC00519281', 62.0),
#  ('2017-02-09', 'USC00519281', 59.0),
#  ('2017-02-08', 'USC00519281', 59.0),
#  ('2017-02-07', 'USC00519281', 64.0),
#  ('2017-02-06', 'USC00519281', 75.0),
#  ('2017-02-05', 'USC00519281', 73.0),
#  ('2017-02-04', 'USC00519281', 70.0),
#  ('2017-02-03', 'USC00519281', 60.0),
#  ('2017-02-02', 'USC00519281', 59.0),
#  ('2017-02-01', 'USC00519281', 68.0),
#  ('2017-01-31', 'USC00519281', 68.0),
#  ('2017-01-30', 'USC00519281', 68.0),
#  ('2017-01-29', 'USC00519281', 69.0),
#  ('2017-01-28', 'USC00519281', 65.0),
#  ('2017-01-27', 'USC00519281', 66.0),
#  ('2017-01-26', 'USC00519281', 70.0),
#  ('2017-01-25', 'USC00519281', 69.0),
#  ('2017-01-24', 'USC00519281', 72.0),
#  ('2017-01-23', 'USC00519281', 72.0),
#  ('2017-01-22', 'USC00519281', 71.0),
#  ('2017-01-21', 'USC00519281', 71.0),
#  ('2017-01-20', 'USC00519281', 69.0),
#  ('2017-01-19', 'USC00519281', 71.0),
#  ('2017-01-18', 'USC00519281', 72.0),
#  ('2017-01-17', 'USC00519281', 69.0),
#  ('2017-01-16', 'USC00519281', 74.0),
#  ('2017-01-15', 'USC00519281', 70.0),
#  ('2017-01-14', 'USC00519281', 77.0),
#  ('2017-01-13', 'USC00519281', 69.0),
#  ('2017-01-12', 'USC00519281', 65.0),
#  ('2017-01-11', 'USC00519281', 63.0),
#  ('2017-01-10', 'USC00519281', 62.0),
#  ('2017-01-09', 'USC00519281', 62.0),
#  ('2017-01-08', 'USC00519281', 70.0),
#  ('2017-01-07', 'USC00519281', 70.0),
#  ('2017-01-06', 'USC00519281', 62.0),
#  ('2017-01-05', 'USC00519281', 63.0),
#  ('2017-01-04', 'USC00519281', 63.0),
#  ('2017-01-03', 'USC00519281', 64.0),
#  ('2017-01-02', 'USC00519281', 70.0),
#  ('2017-01-01', 'USC00519281', 72.0),
#  ('2016-12-31', 'USC00519281', 67.0),
#  ('2016-12-30', 'USC00519281', 69.0),
#  ('2016-12-29', 'USC00519281', 74.0),
#  ('2016-12-28', 'USC00519281', 72.0),
#  ('2016-12-27', 'USC00519281', 71.0),
#  ('2016-12-26', 'USC00519281', 72.0),
#  ('2016-12-25', 'USC00519281', 74.0),
#  ('2016-12-24', 'USC00519281', 74.0),
#  ('2016-12-23', 'USC00519281', 71.0),
#  ('2016-12-22', 'USC00519281', 73.0),
#  ('2016-12-21', 'USC00519281', 74.0),
#  ('2016-12-20', 'USC00519281', 76.0),
#  ('2016-12-19', 'USC00519281', 76.0),
#  ('2016-12-18', 'USC00519281', 69.0),
#  ('2016-12-17', 'USC00519281', 70.0),
#  ('2016-12-16', 'USC00519281', 75.0),
#  ('2016-12-15', 'USC00519281', 62.0),
#  ('2016-12-14', 'USC00519281', 68.0),
#  ('2016-12-13', 'USC00519281', 65.0),
#  ('2016-12-12', 'USC00519281', 66.0),
#  ('2016-12-11', 'USC00519281', 69.0),
#  ('2016-12-10', 'USC00519281', 69.0),
#  ('2016-12-09', 'USC00519281', 68.0),
#  ('2016-12-08', 'USC00519281', 70.0),
#  ('2016-12-07', 'USC00519281', 69.0),
#  ('2016-12-06', 'USC00519281', 67.0),
#  ('2016-12-05', 'USC00519281', 67.0),
#  ('2016-12-04', 'USC00519281', 70.0),
#  ('2016-12-03', 'USC00519281', 72.0),
#  ('2016-12-02', 'USC00519281', 70.0),
#  ('2016-12-01', 'USC00519281', 74.0),
#  ('2016-11-30', 'USC00519281', 73.0),
#  ('2016-11-29', 'USC00519281', 73.0),
#  ('2016-11-28', 'USC00519281', 75.0),
#  ('2016-11-27', 'USC00519281', 73.0),
#  ('2016-11-26', 'USC00519281', 75.0),
#  ('2016-11-25', 'USC00519281', 74.0),
#  ('2016-11-24', 'USC00519281', 75.0),
#  ('2016-11-23', 'USC00519281', 74.0),
#  ('2016-11-22', 'USC00519281', 75.0),
#  ('2016-11-21', 'USC00519281', 73.0),
#  ('2016-11-20', 'USC00519281', 75.0),
#  ('2016-11-19', 'USC00519281', 73.0),
#  ('2016-11-18', 'USC00519281', 75.0),
#  ('2016-11-17', 'USC00519281', 76.0),
#  ('2016-11-16', 'USC00519281', 75.0),
#  ('2016-11-15', 'USC00519281', 76.0),
#  ('2016-11-14', 'USC00519281', 76.0),
#  ('2016-11-13', 'USC00519281', 77.0),
#  ('2016-11-12', 'USC00519281', 74.0),
#  ('2016-11-11', 'USC00519281', 77.0),
#  ('2016-11-10', 'USC00519281', 67.0),
#  ('2016-11-09', 'USC00519281', 68.0),
#  ('2016-11-08', 'USC00519281', 70.0),
#  ('2016-11-07', 'USC00519281', 63.0),
#  ('2016-11-06', 'USC00519281', 71.0),
#  ('2016-11-05', 'USC00519281', 75.0),
#  ('2016-11-04', 'USC00519281', 75.0),
#  ('2016-11-03', 'USC00519281', 75.0),
#  ('2016-11-02', 'USC00519281', 75.0),
#  ('2016-11-01', 'USC00519281', 74.0),
#  ('2016-10-31', 'USC00519281', 76.0),
#  ('2016-10-30', 'USC00519281', 76.0),
#  ('2016-10-29', 'USC00519281', 77.0),
#  ('2016-10-28', 'USC00519281', 74.0),
#  ('2016-10-27', 'USC00519281', 76.0),
#  ('2016-10-26', 'USC00519281', 73.0),
#  ('2016-10-25', 'USC00519281', 76.0),
#  ('2016-10-24', 'USC00519281', 75.0),
#  ('2016-10-23', 'USC00519281', 74.0),
#  ('2016-10-22', 'USC00519281', 77.0),
#  ('2016-10-21', 'USC00519281', 78.0),
#  ('2016-10-20', 'USC00519281', 78.0),
#  ('2016-10-19', 'USC00519281', 78.0),
#  ('2016-10-18', 'USC00519281', 78.0),
#  ('2016-10-17', 'USC00519281', 77.0),
#  ('2016-10-16', 'USC00519281', 79.0),
#  ('2016-10-15', 'USC00519281', 77.0),
#  ('2016-10-14', 'USC00519281', 79.0),
#  ('2016-10-13', 'USC00519281', 78.0),
#  ('2016-10-12', 'USC00519281', 79.0),
#  ('2016-10-11', 'USC00519281', 77.0),
#  ('2016-10-10', 'USC00519281', 71.0),
#  ('2016-10-09', 'USC00519281', 72.0),
#  ('2016-10-08', 'USC00519281', 73.0),
#  ('2016-10-07', 'USC00519281', 76.0),
#  ('2016-10-06', 'USC00519281', 75.0),
#  ('2016-10-05', 'USC00519281', 79.0),
#  ('2016-10-04', 'USC00519281', 79.0),
#  ('2016-10-03', 'USC00519281', 79.0),
#  ('2016-10-02', 'USC00519281', 79.0),
#  ('2016-10-01', 'USC00519281', 77.0),
#  ('2016-09-30', 'USC00519281', 78.0),
#  ('2016-09-29', 'USC00519281', 78.0),
#  ('2016-09-28', 'USC00519281', 78.0),
#  ('2016-09-27', 'USC00519281', 80.0),
#  ('2016-09-26', 'USC00519281', 77.0),
#  ('2016-09-25', 'USC00519281', 79.0),
#  ('2016-09-24', 'USC00519281', 79.0),
#  ('2016-09-23', 'USC00519281', 78.0),
#  ('2016-09-22', 'USC00519281', 77.0),
#  ('2016-09-21', 'USC00519281', 74.0),
#  ('2016-09-20', 'USC00519281', 76.0),
#  ('2016-09-19', 'USC00519281', 78.0),
#  ('2016-09-18', 'USC00519281', 78.0),
#  ('2016-09-17', 'USC00519281', 79.0),
#  ('2016-09-16', 'USC00519281', 78.0),
#  ('2016-09-15', 'USC00519281', 79.0),
#  ('2016-09-14', 'USC00519281', 75.0),
#  ('2016-09-13', 'USC00519281', 79.0),
#  ('2016-09-12', 'USC00519281', 76.0),
#  ('2016-09-11', 'USC00519281', 80.0),
#  ('2016-09-10', 'USC00519281', 77.0),
#  ('2016-09-09', 'USC00519281', 79.0),
#  ('2016-09-08', 'USC00519281', 80.0),
#  ('2016-09-07', 'USC00519281', 74.0),
#  ('2016-09-06', 'USC00519281', 73.0),
#  ('2016-09-05', 'USC00519281', 78.0),
#  ('2016-09-04', 'USC00519281', 78.0),
#  ('2016-09-03', 'USC00519281', 78.0),
#  ('2016-09-02', 'USC00519281', 80.0),
#  ('2016-09-01', 'USC00519281', 80.0),
#  ('2016-08-31', 'USC00519281', 78.0),
#  ('2016-08-30', 'USC00519281', 77.0),
#  ('2016-08-29', 'USC00519281', 78.0),
#  ('2016-08-28', 'USC00519281', 73.0),
#  ('2016-08-27', 'USC00519281', 75.0),
#  ('2016-08-26', 'USC00519281', 80.0),
#  ('2016-08-25', 'USC00519281', 80.0),
#  ('2016-08-24', 'USC00519281', 77.0),
#  ('2016-08-23', 'USC00519281', 77.0)]

# %%
# Plot the results as a histogram
last_twelve_months_for_USC00519281_df = pd.DataFrame(last_twelve_months_for_USC00519281)
last_twelve_months_for_USC00519281_df

last_twelve_months_for_USC00519281_df.plot.hist(bins=12, figsize = (12, 6), color = 'g', legend = False)
plt.title("Last 12 Months Temperature Frequency of Station USC00519281", fontsize = 20, fontweight = 'bold')
plt.xlabel("Temperature")
plt.ylabel("Count")
plt.savefig('../Images/last_twelve_months_for_USC00519281_histogram.png')
plt.show()

# %% [markdown]
# # Bonus Challenge #1

# %%
# Measurements File to Load 
hawaii_measurements = "../Resources/hawaii_measurements.csv"

# Read Hawaii Measurements File and store into Pandas DataFrame
hawaii_measurements_df = pd.read_csv(hawaii_measurements)
hawaii_measurements_df.head()
# Out:
#        station        date  prcp  tobs
# 0  USC00519397  2010-01-01  0.08    65
# 1  USC00519397  2010-01-02  0.00    63
# 2  USC00519397  2010-01-03  0.00    74
# 3  USC00519397  2010-01-04  0.00    76
# 4  USC00519397  2010-01-06   NaN    73

# %%
# Stations File to Load
hawaii_stations = "../Resources/hawaii_stations.csv"

# Read Hawaii Stations File and store into Pandas DataFrame
hawaii_stations_df = pd.read_csv(hawaii_stations)
hawaii_stations_df.head()
# Out:
#        station                                    name  latitude  longitude  \
# 0  USC00519397                    WAIKIKI 717.2, HI US   21.2716  -157.8168
# 1  USC00513117                    KANEOHE 838.1, HI US   21.4234  -157.8015
# 2  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US   21.5213  -157.8374
# 3  USC00517948                       PEARL CITY, HI US   21.3934  -157.9751
# 4  USC00518838              UPPER WAHIAWA 874.3, HI US   21.4992  -158.0111
#
#    elevation
# 0        3.0
# 1       14.6
# 2        7.0
# 3       11.9
# 4      306.6

# %%
# Merge the two DFs 
merged_stations_and_measurements_df = pd.merge(hawaii_stations_df, hawaii_measurements_df, on = 'station', how = 'left')
merged_stations_and_measurements_df
# Out:
#            station                          name  latitude  longitude  \
# 0      USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 1      USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 2      USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 3      USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 4      USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# ...            ...                           ...       ...        ...
# 19545  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19546  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19547  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19548  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19549  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
#
#        elevation        date  prcp  tobs
# 0            3.0  2010-01-01  0.08    65
# 1            3.0  2010-01-02  0.00    63
# 2            3.0  2010-01-03  0.00    74
# 3            3.0  2010-01-04  0.00    76
# 4            3.0  2010-01-06   NaN    73
# ...          ...         ...   ...   ...
# 19545      152.4  2017-08-19  0.09    71
# 19546      152.4  2017-08-20   NaN    78
# 19547      152.4  2017-08-21  0.56    76
# 19548      152.4  2017-08-22  0.50    76
# 19549      152.4  2017-08-23  0.45    76
#
# [19550 rows x 8 columns]

# %%
# Use the newly merged DF to fetch data by a specific month
merged_stations_and_measurements_df['month'] = pd.DatetimeIndex(merged_stations_and_measurements_df['date']).month
merged_stations_and_measurements_df

# Fetch June Data
june = merged_stations_and_measurements_df.loc[merged_stations_and_measurements_df['month'] == 6]
june
# Out:
#            station                          name  latitude  longitude  \
# 133    USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 134    USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 135    USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 136    USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 137    USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# ...            ...                           ...       ...        ...
# 19492  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19493  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19494  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19495  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19496  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
#
#        elevation        date  prcp  tobs  month
# 133          3.0  2010-06-01  0.00    78      6
# 134          3.0  2010-06-02  0.01    76      6
# 135          3.0  2010-06-03  0.00    78      6
# 136          3.0  2010-06-04  0.00    76      6
# 137          3.0  2010-06-05  0.00    77      6
# ...          ...         ...   ...   ...    ...
# 19492      152.4  2017-06-26  0.02    79      6
# 19493      152.4  2017-06-27  0.10    74      6
# 19494      152.4  2017-06-28  0.02    74      6
# 19495      152.4  2017-06-29  0.04    76      6
# 19496      152.4  2017-06-30  0.20    75      6
#
# [1700 rows x 9 columns]

# %%
# Fetch December Data
december = merged_stations_and_measurements_df.loc[merged_stations_and_measurements_df['month'] == 12]
december
# Out:
#            station                          name  latitude  longitude  \
# 305    USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 306    USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 307    USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 308    USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 309    USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# ...            ...                           ...       ...        ...
# 19323  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19324  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19325  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19326  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19327  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
#
#        elevation        date  prcp  tobs  month
# 305          3.0  2010-12-01  0.04    76     12
# 306          3.0  2010-12-03  0.00    74     12
# 307          3.0  2010-12-04  0.00    74     12
# 308          3.0  2010-12-06  0.00    64     12
# 309          3.0  2010-12-07  0.00    64     12
# ...          ...         ...   ...   ...    ...
# 19323      152.4  2016-12-27  0.14    71     12
# 19324      152.4  2016-12-28  0.14    71     12
# 19325      152.4  2016-12-29  1.03    69     12
# 19326      152.4  2016-12-30  2.37    65     12
# 19327      152.4  2016-12-31  0.90    65     12
#
# [1517 rows x 9 columns]

# %%
# Create a distribution curve to give us a better representation of future temperature predictions for
# the months of June and December in Hawaii. This helps us analyze a conclusion noting if there
# are any major differences in temps during these two months.

f, axes = plt.subplots(1,1, figsize=(7, 7), sharex=True)

sb.distplot(june['tobs'], color="red", label = 'june')
sb.distplot(december['tobs'], color="blue", label = 'december')

plt.title('Temperatures in Hawaii 2010 -2017', fontsize = 20, fontweight = 'bold')
plt.xlabel('Temperatures')
plt.ylabel('Frequency')
plt.legend()
plt.tight_layout()
plt.savefig('../Images/temps_in_hawaii_2010_until_2017.png')
plt.show()

# %%
clean_june_group = june.groupby(["station"])
clean_june_group

avg_temp = round(clean_june_group["tobs"].mean(), 2)
avg_temp

avg_june_temp_df = pd.DataFrame({'Avg. Temp': avg_temp})
avg_june_temp_df
# Out:
#              Avg. Temp
# station
# USC00511918      74.14
# USC00513117      74.05
# USC00514830      76.01
# USC00516128      71.94
# USC00517948      76.66
# USC00518838      73.39
# USC00519281      73.27
# USC00519397      77.56
# USC00519523      76.67

# %%
# Here we find the avg. Temps for each station in December

clean_december_group = december.groupby(["station"])
clean_december_group

avg_temp = round(clean_december_group["tobs"].mean(), 2)
avg_temp

avg_december_temp_df = pd.DataFrame({'Avg. Temp': avg_temp})
avg_december_temp_df
# Out:
#              Avg. Temp
# station
# USC00511918      69.68
# USC00513117      71.07
# USC00514830      73.22
# USC00516128      69.29
# USC00517948      71.83
# USC00518838      72.42
# USC00519281      69.90
# USC00519397      71.11
# USC00519523      72.43

# %%
# This summarizes our statistics for further analysis. For example we could create
# a box and whisker between the upper and lower quartiles to compare with another month.

avg_december_temp_df_stats = avg_december_temp_df.describe()
avg_december_temp_df_stats
# Out:
#        Avg. Temp
# count   9.000000
# mean   71.216667
# std     1.376118
# min    69.290000
# 25%    69.900000
# 50%    71.110000
# 75%    72.420000
# max    73.220000

# %%
# We can compare these stats with Decembers stats.
avg_june_temp_df_stats = avg_june_temp_df.describe()
avg_june_temp_df_stats
# Out:
#        Avg. Temp
# count   9.000000
# mean   74.854444
# std     1.920879
# min    71.940000
# 25%    73.390000
# 50%    74.140000
# 75%    76.660000
# max    77.560000

# %% [markdown]
# Assuming a paired t-test and a significance level of 0.05 - From 2010 -2017, June had a mean temperature of 74.85 degrees Fahrenheit while December had a mean temperature of 71.22. The Standard Deviation was 1.921 and 1.377 respectively with 1700 and 1517 datapoints respectively as well. After finding our t-value of 62.09 we concurred the the probability was very close to 1. After comparing our probability (p-value) to our significance level of 0.05 we see that our p-value is significantly greater than 0.05 suggesting that the mean on June and the Mean of December has no difference in temperatures between the two months. This further alsos us to accept the null hypothesis (assuming all conditions for inference are met).

# %% [markdown]
# ## Bonus Challenge Assignment

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-04-28', '2012-05-05'))
# Out:
# [(66.0, 72.25, 78.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
print(calc_temps('2010-07-04', '2010-07-11'))
# Out:
# [(68.0, 73.73846153846154, 81.0)]

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
my_trip_previous_year = calc_temps('2010-07-04', '2010-07-11')
my_trip_previous_year

my_trip_previous_year_df = pd.DataFrame(my_trip_previous_year, columns = ['TMIN', 'TAVG', 'TMAX'])
my_trip_previous_year_df

error = my_trip_previous_year_df['TMAX'] - my_trip_previous_year_df['TMIN']

my_trip_previous_year_df.plot(kind = 'bar', yerr=error)
plt.title("Trip Avg Temp", fontsize = 16, fontweight = 'bold')
plt.ylabel("Temp (F)")
plt.xlabel("Values")
plt.tight_layout()
plt.savefig('../Images/previous_year_vacation_date_avg_temps.png')
plt.show()

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
start_date = '2010-07-04'
end_date = '2010-07-11'

total_rainfall_per_station_previous_year = session.query(Measurement.station, Measurement.prcp, 
                                                         Station.name, Station.latitude, Station.longitude, 
                                                         Station.elevation).\
filter(Measurement.date >= start_date).\
filter(Measurement.date <= end_date).\
    order_by(Measurement.prcp.desc()).all()
total_rainfall_per_station_previous_year
# Out:
# [('USC00516128', 1.05, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00516128', 1.05, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   1.05,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00516128', 1.05, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00516128',
#   1.05,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00516128',
#   1.05,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00516128',
#   1.05,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   1.05,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00516128',
#   1.05,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128', 1.01, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00516128', 1.01, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   1.01,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00516128', 1.01, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00516128',
#   1.01,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00516128',
#   1.01,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00516128',
#   1.01,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   1.01,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00516128',
#   1.01,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128', 0.9, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00516128', 0.9, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   0.9,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00516128', 0.9, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00516128', 0.9, 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  ('USC00516128',
#   0.9,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00516128',
#   0.9,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   0.9,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00516128',
#   0.9,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128', 0.75, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00516128', 0.75, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   0.75,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00516128', 0.75, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00516128',
#   0.75,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00516128',
#   0.75,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00516128',
#   0.75,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   0.75,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00516128',
#   0.75,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128', 0.75, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00516128', 0.75, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   0.75,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00516128', 0.75, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00516128',
#   0.75,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00516128',
#   0.75,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00516128',
#   0.75,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   0.75,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00516128',
#   0.75,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00518838', 0.44, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00518838', 0.44, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00518838',
#   0.44,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00518838', 0.44, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00518838',
#   0.44,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00518838',
#   0.44,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00518838',
#   0.44,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00518838',
#   0.44,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00518838',
#   0.44,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128', 0.44, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00516128', 0.44, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   0.44,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00516128', 0.44, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00516128',
#   0.44,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00516128',
#   0.44,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00516128',
#   0.44,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   0.44,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00516128',
#   0.44,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00518838', 0.41, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00518838', 0.41, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00518838',
#   0.41,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00518838', 0.41, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00518838',
#   0.41,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00518838',
#   0.41,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00518838',
#   0.41,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00518838',
#   0.41,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00518838',
#   0.41,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281', 0.38, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519281', 0.38, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519281',
#   0.38,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519281', 0.38, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519281',
#   0.38,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519281',
#   0.38,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519281',
#   0.38,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519281',
#   0.38,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519281',
#   0.38,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128', 0.31, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00516128', 0.31, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   0.31,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00516128', 0.31, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00516128',
#   0.31,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00516128',
#   0.31,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00516128',
#   0.31,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   0.31,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00516128',
#   0.31,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523', 0.21, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519523', 0.21, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519523',
#   0.21,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519523', 0.21, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519523',
#   0.21,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519523',
#   0.21,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519523',
#   0.21,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519523',
#   0.21,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519523',
#   0.21,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281', 0.21, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519281', 0.21, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519281',
#   0.21,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519281', 0.21, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519281',
#   0.21,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519281',
#   0.21,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519281',
#   0.21,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519281',
#   0.21,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519281',
#   0.21,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281', 0.19, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519281', 0.19, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519281',
#   0.19,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519281', 0.19, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519281',
#   0.19,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519281',
#   0.19,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519281',
#   0.19,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519281',
#   0.19,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519281',
#   0.19,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00514830', 0.15, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00514830', 0.15, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00514830',
#   0.15,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00514830', 0.15, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00514830',
#   0.15,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00514830',
#   0.15,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00514830',
#   0.15,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00514830',
#   0.15,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00514830',
#   0.15,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00511918', 0.15, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00511918', 0.15, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00511918',
#   0.15,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00511918', 0.15, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00511918',
#   0.15,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00511918',
#   0.15,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00511918',
#   0.15,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00511918',
#   0.15,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00511918',
#   0.15,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00514830', 0.14, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00514830', 0.14, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00514830',
#   0.14,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00514830', 0.14, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00514830',
#   0.14,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00514830',
#   0.14,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00514830',
#   0.14,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00514830',
#   0.14,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00514830',
#   0.14,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281', 0.14, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519281', 0.14, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519281',
#   0.14,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519281', 0.14, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519281',
#   0.14,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519281',
#   0.14,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519281',
#   0.14,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519281',
#   0.14,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519281',
#   0.14,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128', 0.14, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00516128', 0.14, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   0.14,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00516128', 0.14, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00516128',
#   0.14,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00516128',
#   0.14,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00516128',
#   0.14,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   0.14,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00516128',
#   0.14,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 0.11, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00513117', 0.11, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00513117',
#   0.11,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00513117', 0.11, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00513117',
#   0.11,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00513117',
#   0.11,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00513117',
#   0.11,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117',
#   0.11,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00513117',
#   0.11,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00518838', 0.11, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00518838', 0.11, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00518838',
#   0.11,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00518838', 0.11, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00518838',
#   0.11,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00518838',
#   0.11,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00518838',
#   0.11,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00518838',
#   0.11,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00518838',
#   0.11,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523', 0.1, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519523', 0.1, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519523',
#   0.1,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519523', 0.1, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519523', 0.1, 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  ('USC00519523',
#   0.1,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519523',
#   0.1,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519523',
#   0.1,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519523',
#   0.1,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00511918', 0.1, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00511918', 0.1, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00511918',
#   0.1,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00511918', 0.1, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00511918', 0.1, 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  ('USC00511918',
#   0.1,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00511918',
#   0.1,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00511918',
#   0.1,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00511918',
#   0.1,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519397', 0.09, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519397', 0.09, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519397',
#   0.09,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519397', 0.09, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519397',
#   0.09,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519397',
#   0.09,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519397',
#   0.09,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519397',
#   0.09,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519397',
#   0.09,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 0.09, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00513117', 0.09, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00513117',
#   0.09,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00513117', 0.09, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00513117',
#   0.09,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00513117',
#   0.09,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00513117',
#   0.09,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117',
#   0.09,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00513117',
#   0.09,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00514830', 0.09, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00514830', 0.09, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00514830',
#   0.09,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00514830', 0.09, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00514830',
#   0.09,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00514830',
#   0.09,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00514830',
#   0.09,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00514830',
#   0.09,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00514830',
#   0.09,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00518838', 0.09, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00518838', 0.09, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00518838',
#   0.09,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00518838', 0.09, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00518838',
#   0.09,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00518838',
#   0.09,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00518838',
#   0.09,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00518838',
#   0.09,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00518838',
#   0.09,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519397', 0.08, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519397', 0.08, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519397',
#   0.08,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519397', 0.08, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519397',
#   0.08,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519397',
#   0.08,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519397',
#   0.08,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519397',
#   0.08,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519397',
#   0.08,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519397', 0.08, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519397', 0.08, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519397',
#   0.08,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519397', 0.08, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519397',
#   0.08,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519397',
#   0.08,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519397',
#   0.08,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519397',
#   0.08,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519397',
#   0.08,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00514830', 0.08, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00514830', 0.08, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00514830',
#   0.08,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00514830', 0.08, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00514830',
#   0.08,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00514830',
#   0.08,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00514830',
#   0.08,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00514830',
#   0.08,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00514830',
#   0.08,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00517948', 0.08, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00517948', 0.08, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00517948',
#   0.08,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00517948', 0.08, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00517948',
#   0.08,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00517948',
#   0.08,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00517948',
#   0.08,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00517948',
#   0.08,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00517948',
#   0.08,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523', 0.08, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519523', 0.08, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519523',
#   0.08,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519523', 0.08, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519523',
#   0.08,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519523',
#   0.08,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519523',
#   0.08,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519523',
#   0.08,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519523',
#   0.08,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281', 0.08, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519281', 0.08, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519281',
#   0.08,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519281', 0.08, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519281',
#   0.08,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519281',
#   0.08,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519281',
#   0.08,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519281',
#   0.08,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519281',
#   0.08,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 0.07, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00513117', 0.07, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00513117',
#   0.07,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00513117', 0.07, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00513117',
#   0.07,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00513117',
#   0.07,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00513117',
#   0.07,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117',
#   0.07,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00513117',
#   0.07,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519397', 0.06, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519397', 0.06, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519397',
#   0.06,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519397', 0.06, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519397',
#   0.06,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519397',
#   0.06,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519397',
#   0.06,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519397',
#   0.06,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519397',
#   0.06,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519397', 0.06, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519397', 0.06, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519397',
#   0.06,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519397', 0.06, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519397',
#   0.06,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519397',
#   0.06,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519397',
#   0.06,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519397',
#   0.06,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519397',
#   0.06,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00514830', 0.06, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00514830', 0.06, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00514830',
#   0.06,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00514830', 0.06, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00514830',
#   0.06,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00514830',
#   0.06,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00514830',
#   0.06,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00514830',
#   0.06,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00514830',
#   0.06,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523', 0.06, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519523', 0.06, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519523',
#   0.06,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519523', 0.06, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519523',
#   0.06,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519523',
#   0.06,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519523',
#   0.06,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519523',
#   0.06,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519523',
#   0.06,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281', 0.06, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519281', 0.06, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519281',
#   0.06,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519281', 0.06, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519281',
#   0.06,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519281',
#   0.06,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519281',
#   0.06,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519281',
#   0.06,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519281',
#   0.06,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519397', 0.05, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519397', 0.05, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519397',
#   0.05,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519397', 0.05, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519397',
#   0.05,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519397',
#   0.05,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519397',
#   0.05,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519397',
#   0.05,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519397',
#   0.05,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 0.05, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00513117', 0.05, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00513117',
#   0.05,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00513117', 0.05, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00513117',
#   0.05,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00513117',
#   0.05,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00513117',
#   0.05,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117',
#   0.05,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00513117',
#   0.05,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00517948', 0.05, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00517948', 0.05, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00517948',
#   0.05,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00517948', 0.05, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00517948',
#   0.05,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00517948',
#   0.05,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00517948',
#   0.05,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00517948',
#   0.05,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00517948',
#   0.05,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523', 0.05, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519523', 0.05, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519523',
#   0.05,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519523', 0.05, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519523',
#   0.05,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519523',
#   0.05,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519523',
#   0.05,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519523',
#   0.05,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519523',
#   0.05,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 0.04, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00513117', 0.04, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00513117',
#   0.04,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00513117', 0.04, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00513117',
#   0.04,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00513117',
#   0.04,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00513117',
#   0.04,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117',
#   0.04,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00513117',
#   0.04,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 0.04, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00513117', 0.04, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00513117',
#   0.04,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00513117', 0.04, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00513117',
#   0.04,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00513117',
#   0.04,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00513117',
#   0.04,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117',
#   0.04,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00513117',
#   0.04,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519397', 0.03, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519397', 0.03, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519397',
#   0.03,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519397', 0.03, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519397',
#   0.03,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519397',
#   0.03,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519397',
#   0.03,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519397',
#   0.03,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519397',
#   0.03,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 0.03, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00513117', 0.03, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00513117',
#   0.03,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00513117', 0.03, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00513117',
#   0.03,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00513117',
#   0.03,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00513117',
#   0.03,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117',
#   0.03,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00513117',
#   0.03,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00517948', 0.03, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00517948', 0.03, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00517948',
#   0.03,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00517948', 0.03, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00517948',
#   0.03,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00517948',
#   0.03,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00517948',
#   0.03,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00517948',
#   0.03,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00517948',
#   0.03,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00518838', 0.03, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00518838', 0.03, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00518838',
#   0.03,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00518838', 0.03, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00518838',
#   0.03,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00518838',
#   0.03,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00518838',
#   0.03,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00518838',
#   0.03,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00518838',
#   0.03,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00511918', 0.03, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00511918', 0.03, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00511918',
#   0.03,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00511918', 0.03, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00511918',
#   0.03,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00511918',
#   0.03,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00511918',
#   0.03,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00511918',
#   0.03,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00511918',
#   0.03,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 0.02, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00513117', 0.02, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00513117',
#   0.02,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00513117', 0.02, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00513117',
#   0.02,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00513117',
#   0.02,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00513117',
#   0.02,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117',
#   0.02,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00513117',
#   0.02,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523', 0.02, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519523', 0.02, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519523',
#   0.02,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519523', 0.02, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519523',
#   0.02,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519523',
#   0.02,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519523',
#   0.02,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519523',
#   0.02,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519523',
#   0.02,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281', 0.02, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519281', 0.02, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519281',
#   0.02,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519281', 0.02, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519281',
#   0.02,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519281',
#   0.02,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519281',
#   0.02,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519281',
#   0.02,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519281',
#   0.02,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00511918', 0.02, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00511918', 0.02, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00511918',
#   0.02,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00511918', 0.02, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00511918',
#   0.02,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00511918',
#   0.02,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00511918',
#   0.02,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00511918',
#   0.02,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00511918',
#   0.02,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00514830', 0.01, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00514830', 0.01, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00514830',
#   0.01,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00514830', 0.01, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00514830',
#   0.01,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00514830',
#   0.01,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00514830',
#   0.01,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00514830',
#   0.01,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00514830',
#   0.01,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00518838', 0.01, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00518838', 0.01, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00518838',
#   0.01,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00518838', 0.01, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00518838',
#   0.01,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00518838',
#   0.01,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00518838',
#   0.01,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00518838',
#   0.01,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00518838',
#   0.01,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523', 0.01, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519523', 0.01, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519523',
#   0.01,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519523', 0.01, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519523',
#   0.01,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00519523',
#   0.01,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519523',
#   0.01,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519523',
#   0.01,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519523',
#   0.01,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00511918', 0.01, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00511918', 0.01, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00511918',
#   0.01,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00511918', 0.01, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00511918',
#   0.01,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00511918',
#   0.01,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00511918',
#   0.01,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00511918',
#   0.01,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00511918',
#   0.01,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00511918', 0.01, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00511918', 0.01, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00511918',
#   0.01,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00511918', 0.01, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00511918',
#   0.01,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00511918',
#   0.01,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00511918',
#   0.01,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00511918',
#   0.01,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00511918',
#   0.01,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519397', 0.0, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519397', 0.0, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519397',
#   0.0,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519397', 0.0, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519397', 0.0, 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  ('USC00519397',
#   0.0,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519397',
#   0.0,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519397',
#   0.0,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519397',
#   0.0,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00514830', 0.0, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00514830', 0.0, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00514830',
#   0.0,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00514830', 0.0, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00514830', 0.0, 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  ('USC00514830',
#   0.0,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00514830',
#   0.0,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00514830',
#   0.0,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00514830',
#   0.0,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523', 0.0, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519523', 0.0, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519523',
#   0.0,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519523', 0.0, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519523', 0.0, 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  ('USC00519523',
#   0.0,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519523',
#   0.0,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519523',
#   0.0,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519523',
#   0.0,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281', 0.0, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00519281', 0.0, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519281',
#   0.0,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519281', 0.0, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00519281', 0.0, 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  ('USC00519281',
#   0.0,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519281',
#   0.0,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519281',
#   0.0,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519281',
#   0.0,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00511918', 0.0, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00511918', 0.0, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00511918',
#   0.0,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00511918', 0.0, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00511918', 0.0, 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  ('USC00511918',
#   0.0,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00511918',
#   0.0,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00511918',
#   0.0,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00511918',
#   0.0,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00517948', None, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00517948', None, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00517948',
#   None,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00517948', None, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00517948',
#   None,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00517948',
#   None,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00517948',
#   None,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00517948',
#   None,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00517948',
#   None,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00518838', None, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00518838', None, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00518838',
#   None,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00518838', None, 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00518838',
#   None,
#   'UPPER WAHIAWA 874.3, HI US',
#   21.4992,
#   -158.0111,
#   306.6),
#  ('USC00518838',
#   None,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00518838',
#   None,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00518838',
#   None,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00518838',
#   None,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4)]

# %%
# Plot the precipitation totals from lowest to highest. 
total_rainfall_per_station_previous_year = pd.DataFrame(total_rainfall_per_station_previous_year, columns = ['station', 
                                                                                                            'prcp',
                                                                                                            'station name',
                                                                                                            'lat',
                                                                                                            'long.',
                                                                                                            'elevation'])
total_rainfall_per_station_previous_year
# Out:
#          station  prcp                            station name       lat  \
# 0    USC00516128  1.05                    WAIKIKI 717.2, HI US  21.27160
# 1    USC00516128  1.05                    KANEOHE 838.1, HI US  21.42340
# 2    USC00516128  1.05  KUALOA RANCH HEADQUARTERS 886.9, HI US  21.52130
# 3    USC00516128  1.05                       PEARL CITY, HI US  21.39340
# 4    USC00516128  1.05              UPPER WAHIAWA 874.3, HI US  21.49920
# ..           ...   ...                                     ...       ...
# 580  USC00518838   NaN              UPPER WAHIAWA 874.3, HI US  21.49920
# 581  USC00518838   NaN      WAIMANALO EXPERIMENTAL FARM, HI US  21.33556
# 582  USC00518838   NaN                     WAIHEE 837.5, HI US  21.45167
# 583  USC00518838   NaN       HONOLULU OBSERVATORY 702.2, HI US  21.31520
# 584  USC00518838   NaN            MANOA LYON ARBO 785.2, HI US  21.33310
#
#          long.  elevation
# 0   -157.81680        3.0
# 1   -157.80150       14.6
# 2   -157.83740        7.0
# 3   -157.97510       11.9
# 4   -158.01110      306.6
# ..         ...        ...
# 580 -158.01110      306.6
# 581 -157.71139       19.5
# 582 -157.84889       32.9
# 583 -157.99920        0.9
# 584 -157.80250      152.4
#
# [585 rows x 6 columns]

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("07-04")
# Out:
# [(70.0, 76.57142857142857, 81.0)]

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`
normals = []
# Set the start and end date of the trip
start_date = '2010-07-04'
end_date = '2010-07-11'
# Use the start and end date to create a range of dates
vacation_date_range = pd.date_range(start =start_date, end = end_date).strftime("%m-%d")
# Strip off the year and save a list of %m-%d strings
vacation_date_range
# Loop through the list of %m-%d strings and calculate the normals for each date
for date in vacation_date_range:
    dates = {}
    norm = daily_normals(date)
    dates["Date"] = date
    dates["Min"] = norm[0][0]
    dates["Avg"] = norm[0][1]
    dates["Max"] = norm[0][2]

    normals.append(dates)
    
normals
# Out:
# [{'Date': '07-04', 'Min': 70.0, 'Avg': 76.57142857142857, 'Max': 81.0},
#  {'Date': '07-05', 'Min': 66.0, 'Avg': 75.0, 'Max': 81.0},
#  {'Date': '07-06', 'Min': 69.0, 'Avg': 75.0, 'Max': 81.0},
#  {'Date': '07-07', 'Min': 69.0, 'Avg': 74.91071428571429, 'Max': 82.0},
#  {'Date': '07-08', 'Min': 69.0, 'Avg': 76.08333333333333, 'Max': 83.0},
#  {'Date': '07-09', 'Min': 68.0, 'Avg': 76.19298245614036, 'Max': 83.0},
#  {'Date': '07-10', 'Min': 68.0, 'Avg': 75.62068965517241, 'Max': 82.0},
#  {'Date': '07-11', 'Min': 70.0, 'Avg': 75.78947368421052, 'Max': 81.0}]

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index
previous_year_vacation_date_normals = pd.DataFrame(normals).set_index('Date')
previous_year_vacation_date_normals
# Out:
#         Min        Avg   Max
# Date
# 07-04  70.0  76.571429  81.0
# 07-05  66.0  75.000000  81.0
# 07-06  69.0  75.000000  81.0
# 07-07  69.0  74.910714  82.0
# 07-08  69.0  76.083333  83.0
# 07-09  68.0  76.192982  83.0
# 07-10  68.0  75.620690  82.0
# 07-11  70.0  75.789474  81.0

# %%
# Plot the daily normals as an area plot with `stacked=False`
previous_year_vacation_date_normals.plot(kind = 'area', rot = 45, figsize = (10, 6), stacked = False)
plt.title("Previous Year Vacation Temp. Normals", fontsize = 18, fontweight = 'bold')
plt.xlabel("Days of the Trip")
plt.ylabel("Temperature")
plt.savefig('../Images/previous_year_vacation_date_normals.png')
plt.show()
